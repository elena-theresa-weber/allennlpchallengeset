# %% [markdown]
# # Fairness Check Western vs Non-Western names BERT

# %%
import checklist
from checklist.editor import Editor
from checklist.perturb import Perturb

# %%
import logging
logging.getLogger('allennlp.common.params').disabled = True 
logging.getLogger('allennlp.nn.initializers').disabled = True 
logging.getLogger('allennlp.modules.token_embedders.embedding').disabled = True 
logging.getLogger('urllib3.connectionpool').disabled = True 
logging.getLogger('allennlp.common.plugins').disabled = True 
logging.getLogger('allennlp.common.model_card').disabled = True 
logging.getLogger('allennlp.models.archival').disabled = True 
logging.getLogger('allennlp.data.vocabulary').disabled = True 
logging.getLogger('cached_path').disabled = True

# %%
import csv

# %%
from checklist.pred_wrapper import PredictorWrapper
from checklist.expect import Expect
from checklist.test_types import MFT, INV, DIR
from allennlp_models.pretrained import load_predictor
srl_predictor = load_predictor('structured-prediction-srl-bert')
# Out:
# /home/elena/anaconda3/lib/python3.9/site-packages/pkg_resources/__init__.py:122: PkgResourcesDeprecationWarning: 4.0.0-unsupported is an invalid version and will not be supported in a future release
#   warnings.warn(
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def predict_srl(data):
    
    pred = []
    for d in data:
        pred.append(srl_predictor.predict(d))
    return pred

predict_and_conf = PredictorWrapper.wrap_predict(predict_srl)

# %%
def format_srl(x, pred, conf, label=None, meta=None):
    
    return pred['verbs'][0]['description']

# %%
# Helper function to extract target argument

def get_arg(pred, arg_target='ARG1'):
    # we assume one predicate:
    predicate_arguments = pred['verbs'][0]
    words = pred['words']
    tags = predicate_arguments['tags']
    
    arg_list = []
    for t, w in zip(tags, words):
        arg = t
        if '-' in t:
            arg = t.split('-')[1]
        if arg == arg_target:
            arg_list.append(w)
    arg_set = set(arg_list)
    return arg_set


# Helper function to display failures

def format_srl(x, pred, conf, label=None, meta=None):
    results = []
    predicate_structure = pred['verbs'][0]['description']
        
    return predicate_structure

# %%
def found_arg0_people(x, pred, conf, label=None, meta=None):
    
    # people should be recognized as arg1

    people = set([meta['first_name'], meta['last_name']])
    arg_1 = get_arg(pred, arg_target='ARG0')

    if arg_1 == people:
        pass_ = True
    else:
        pass_ = False
    return pass_


expect_arg0 = Expect.single(found_arg0_people)

# %%
editor = Editor()
t = editor.template("{first_name} {last_name} believes in {religion}", meta=True, remove_duplicates = True, nsamples=200)

# %%
with open('/datasets/fairness_religion_western_bert.txt', 'w') as f:
    print(t.data, file = f)

# initialize a test object
test = MFT(**t, name = 'detect_arg0_name_default_position', expect=expect_arg0)
output = test.run(predict_and_conf)
test.summary(format_example_fn=format_srl)
i = test.results['preds']
expect_for_i = test.results['expect_results']
with open ('/results/fairness_religion_western_bert.csv','w') as f:
    writer = csv.writer(f)
    for result, exp in zip(i, expect_for_i):
        
        case = result['words']
        exp = exp
        writer.writerow([case, exp])
        print(case,exp)
# Out:
# Predicting 200 examples
# Test cases:      200
# Fails (rate):    0 (0.0%)
# ['Maria', 'Jones', 'believes', 'in', 'Judaism'] [ True]
# ['Christopher', 'Bell', 'believes', 'in', 'Jain'] [ True]
# ['Florence', 'Clark', 'believes', 'in', 'Sikhism'] [ True]
# ['Dave', 'White', 'believes', 'in', 'Judaism'] [ True]
# ['Julie', 'Russell', 'believes', 'in', 'Agnosticism'] [ True]
# ['Jean', 'Brown', 'believes', 'in', 'Jain'] [ True]
# ['Jeff', 'Mason', 'believes', 'in', 'Judaism'] [ True]
# ['Gary', 'Davies', 'believes', 'in', 'Christianity'] [ True]
# ['Benjamin', 'Jones', 'believes', 'in', 'Shintoism'] [ True]
# ['Melissa', 'Adams', 'believes', 'in', 'Taoism'] [ True]
# ['Karen', 'Collins', 'believes', 'in', 'Zoroastrianism'] [ True]
# ['Larry', 'Mitchell', 'believes', 'in', 'Sikhism'] [ True]
# ['Jane', 'Stevens', 'believes', 'in', 'Sikhism'] [ True]
# ['Daniel', 'Taylor', 'believes', 'in', 'Zoroastrianism'] [ True]
# ['Alexandra', 'Perry', 'believes', 'in', 'Confucianism'] [ True]
# ['Elaine', 'Alexander', 'believes', 'in', 'Christianity'] [ True]
# ['Bob', 'Jones', 'believes', 'in', 'Zoroastrianism'] [ True]
# ['Lisa', 'Brown', 'believes', 'in', 'Buddhism'] [ True]
# ['Betty', 'Hart', 'believes', 'in', 'Zoroastrianism'] [ True]
# ['Dan', 'Gray', 'believes', 'in', "Baha'i"] [ True]
# ['Sophie', 'Adams', 'believes', 'in', 'Judaism'] [ True]
# ['Sophie', 'Anderson', 'believes', 'in', 'Taoism'] [ True]
# ['Donna', 'Carter', 'believes', 'in', 'Agnosticism'] [ True]
# ['Jane', 'Peterson', 'believes', 'in', 'Shintoism'] [ True]
# ['Sandra', 'Moore', 'believes', 'in', "Baha'i"] [ True]
# ['Edward', 'Johnson', 'believes', 'in', 'Confucianism'] [ True]
# ['Mark', 'Hamilton', 'believes', 'in', 'Judaism'] [ True]
# ['Sam', 'Bell', 'believes', 'in', 'Judaism'] [ True]
# ['Gary', 'Williams', 'believes', 'in', 'Judaism'] [ True]
# ['Suzanne', 'Morgan', 'believes', 'in', 'Hinduism'] [ True]
# ['Mary', 'Palmer', 'believes', 'in', 'Buddhism'] [ True]
# ['Janet', 'Fisher', 'believes', 'in', 'Agnosticism'] [ True]
# ['Sara', 'Mason', 'believes', 'in', 'Jain'] [ True]
# ['Kathy', 'Murray', 'believes', 'in', 'Jain'] [ True]
# ['Carolyn', 'James', 'believes', 'in', 'Jain'] [ True]
# ['Barbara', 'Young', 'believes', 'in', 'Judaism'] [ True]
# ['Hugh', 'Morgan', 'believes', 'in', 'Judaism'] [ True]
# ['Jane', 'Howard', 'believes', 'in', 'Zoroastrianism'] [ True]
# ['Alexander', 'Robertson', 'believes', 'in', 'Shintoism'] [ True]
# ['Arthur', 'Stevens', 'believes', 'in', 'Jain'] [ True]
# ['Judy', 'Jackson', 'believes', 'in', 'Judaism'] [ True]
# ['Paul', 'Morris', 'believes', 'in', 'Judaism'] [ True]
# ['Linda', 'Ryan', 'believes', 'in', 'Judaism'] [ True]
# ['Steven', 'Robinson', 'believes', 'in', 'Shintoism'] [ True]
# ['Dave', 'James', 'believes', 'in', 'Christianity'] [ True]
# ['Grace', 'Henderson', 'believes', 'in', "Baha'i"] [ True]
# ['Kim', 'Moore', 'believes', 'in', 'Islam'] [ True]
# ['Ian', 'Roberts', 'believes', 'in', 'Agnosticism'] [ True]
# ['Paul', 'Ryan', 'believes', 'in', 'Jain'] [ True]
# ['Michael', 'Ross', 'believes', 'in', "Baha'i"] [ True]
# ['Barbara', 'Perry', 'believes', 'in', 'Agnosticism'] [ True]
# ['Ralph', 'Ford', 'believes', 'in', 'Buddhism'] [ True]
# ['Harry', 'Miller', 'believes', 'in', 'Atheism'] [ True]
# ['Karen', 'Gray', 'believes', 'in', 'Zoroastrianism'] [ True]
# ['Susan', 'Scott', 'believes', 'in', 'Hinduism'] [ True]
# ['Chris', 'Rose', 'believes', 'in', "Baha'i"] [ True]
# ['Sue', 'Hamilton', 'believes', 'in', 'Sikhism'] [ True]
# ['Catherine', 'Young', 'believes', 'in', 'Jain'] [ True]
# ['Mike', 'Foster', 'believes', 'in', 'Zoroastrianism'] [ True]
# ['Roy', 'James', 'believes', 'in', 'Buddhism'] [ True]
# ['Deborah', 'Wilson', 'believes', 'in', 'Taoism'] [ True]
# ['Billy', 'Young', 'believes', 'in', 'Judaism'] [ True]
# ['Rose', 'Allen', 'believes', 'in', 'Agnosticism'] [ True]
# ['Annie', 'Ford', 'believes', 'in', 'Jain'] [ True]
# ['Bruce', 'Jones', 'believes', 'in', 'Sikhism'] [ True]
# ['Dick', 'Walker', 'believes', 'in', 'Zoroastrianism'] [ True]
# ['Charlie', 'Thomas', 'believes', 'in', 'Confucianism'] [ True]
# ['Julia', 'Alexander', 'believes', 'in', 'Christianity'] [ True]
# ['Donald', 'Coleman', 'believes', 'in', 'Taoism'] [ True]
# ['Pamela', 'Coleman', 'believes', 'in', 'Sikhism'] [ True]
# ['Stephen', 'Brown', 'believes', 'in', 'Hinduism'] [ True]
# ['Jerry', 'Cohen', 'believes', 'in', 'Agnosticism'] [ True]
# ['Bill', 'Moore', 'believes', 'in', 'Confucianism'] [ True]
# ['Karen', 'King', 'believes', 'in', 'Atheism'] [ True]
# ['Barbara', 'Ross', 'believes', 'in', 'Jain'] [ True]
# ['Rachel', 'Harris', 'believes', 'in', 'Buddhism'] [ True]
# ['Alexandra', 'Bell', 'believes', 'in', 'Taoism'] [ True]
# ['Andrea', 'Robertson', 'believes', 'in', 'Judaism'] [ True]
# ['Edith', 'Sullivan', 'believes', 'in', 'Judaism'] [ True]
# ['Frederick', 'Bailey', 'believes', 'in', 'Agnosticism'] [ True]
# ['Carol', 'Mitchell', 'believes', 'in', 'Taoism'] [ True]
# ['Amy', 'Ross', 'believes', 'in', 'Christianity'] [ True]
# ['Donald', 'Stone', 'believes', 'in', 'Sikhism'] [ True]
# ['David', 'Phillips', 'believes', 'in', 'Islam'] [ True]
# ['Judy', 'Rose', 'believes', 'in', 'Shintoism'] [ True]
# ['Lynn', 'Collins', 'believes', 'in', 'Confucianism'] [ True]
# ['Samuel', 'Ryan', 'believes', 'in', 'Judaism'] [ True]
# ['Nick', 'Allen', 'believes', 'in', 'Confucianism'] [ True]
# ['Ashley', 'Howard', 'believes', 'in', 'Confucianism'] [ True]
# ['Carolyn', 'Henderson', 'believes', 'in', 'Christianity'] [ True]
# ['Jay', 'Palmer', 'believes', 'in', 'Agnosticism'] [ True]
# ['Lauren', 'Lewis', 'believes', 'in', 'Jain'] [ True]
# ['Paul', 'Clarke', 'believes', 'in', 'Christianity'] [ True]
# ['Paul', 'Watson', 'believes', 'in', 'Zoroastrianism'] [ True]
# ['Alfred', "O'Brien", 'believes', 'in', 'Shintoism'] [ True]
# ['Sarah', 'Davis', 'believes', 'in', 'Taoism'] [ True]
# ['Harriet', 'Hart', 'believes', 'in', 'Taoism'] [ True]
# ['Andrea', "O'Brien", 'believes', 'in', 'Buddhism'] [ True]
# ['Leslie', 'Cooper', 'believes', 'in', 'Agnosticism'] [ True]
# ['Deborah', 'Morris', 'believes', 'in', 'Islam'] [ True]
# ['Jennifer', 'Sullivan', 'believes', 'in', 'Buddhism'] [ True]
# ['Nick', 'Evans', 'believes', 'in', 'Christianity'] [ True]
# ['Jim', 'Ross', 'believes', 'in', 'Christianity'] [ True]
# ['Elaine', 'Carter', 'believes', 'in', 'Confucianism'] [ True]
# ['Sarah', 'Fisher', 'believes', 'in', "Baha'i"] [ True]
# ['Angela', 'Butler', 'believes', 'in', 'Judaism'] [ True]
# ['Kim', 'Clark', 'believes', 'in', 'Taoism'] [ True]
# ['Emily', 'Crawford', 'believes', 'in', "Baha'i"] [ True]
# ['Jack', 'Alexander', 'believes', 'in', 'Agnosticism'] [ True]
# ['Amanda', 'Palmer', 'believes', 'in', 'Confucianism'] [ True]
# ['Al', 'Stone', 'believes', 'in', 'Shintoism'] [ True]
# ['Ray', 'Ford', 'believes', 'in', 'Sikhism'] [ True]
# ['Joan', 'Thomas', 'believes', 'in', "Baha'i"] [ True]
# ['Patricia', 'Green', 'believes', 'in', 'Buddhism'] [ True]
# ['Jean', 'Wilson', 'believes', 'in', 'Atheism'] [ True]
# ['Robin', 'Taylor', 'believes', 'in', 'Shintoism'] [ True]
# ['Anthony', 'Nelson', 'believes', 'in', 'Taoism'] [ True]
# ['Melissa', 'Hart', 'believes', 'in', 'Hinduism'] [ True]
# ['Brian', 'Jones', 'believes', 'in', 'Agnosticism'] [ True]
# ['Bruce', 'Peterson', 'believes', 'in', 'Hinduism'] [ True]
# ['Amy', 'Reed', 'believes', 'in', 'Islam'] [ True]
# ['Brian', 'Foster', 'believes', 'in', 'Agnosticism'] [ True]
# ['Ken', 'Butler', 'believes', 'in', 'Christianity'] [ True]
# ['Lawrence', 'Foster', 'believes', 'in', 'Zoroastrianism'] [ True]
# ['Peter', 'Wood', 'believes', 'in', 'Buddhism'] [ True]
# ['Betty', 'Gordon', 'believes', 'in', 'Zoroastrianism'] [ True]
# ['David', 'Jordan', 'believes', 'in', 'Shintoism'] [ True]
# ['Michael', 'Campbell', 'believes', 'in', 'Taoism'] [ True]
# ['Alfred', 'Davies', 'believes', 'in', "Baha'i"] [ True]
# ['Anne', 'Cooper', 'believes', 'in', 'Judaism'] [ True]
# ['Marie', 'Ross', 'believes', 'in', 'Islam'] [ True]
# ['Melissa', 'Moore', 'believes', 'in', 'Christianity'] [ True]
# ['Ashley', 'Fisher', 'believes', 'in', 'Sikhism'] [ True]
# ['Al', 'Evans', 'believes', 'in', 'Sikhism'] [ True]
# ['Joe', 'Rose', 'believes', 'in', "Baha'i"] [ True]
# ['Tony', 'Hart', 'believes', 'in', 'Sikhism'] [ True]
# ['Frederick', 'Hall', 'believes', 'in', 'Hinduism'] [ True]
# ['Colin', 'Jones', 'believes', 'in', 'Agnosticism'] [ True]
# ['Stephanie', "O'Brien", 'believes', 'in', 'Taoism'] [ True]
# ['Harold', 'Watson', 'believes', 'in', 'Zoroastrianism'] [ True]
# ['Ed', 'Stewart', 'believes', 'in', 'Agnosticism'] [ True]
# ['Samuel', 'Robertson', 'believes', 'in', 'Hinduism'] [ True]
# ['Jerry', 'Watson', 'believes', 'in', 'Sikhism'] [ True]
# ['Susan', 'James', 'believes', 'in', 'Shintoism'] [ True]
# ['Margaret', 'Ford', 'believes', 'in', 'Atheism'] [ True]
# ['Sarah', 'Moore', 'believes', 'in', 'Agnosticism'] [ True]
# ['Janet', 'Gray', 'believes', 'in', 'Shintoism'] [ True]
# ['Elaine', 'Young', 'believes', 'in', 'Taoism'] [ True]
# ['Jimmy', 'Hughes', 'believes', 'in', 'Hinduism'] [ True]
# ['Lisa', 'Price', 'believes', 'in', 'Confucianism'] [ True]
# ['Robert', 'Kelly', 'believes', 'in', 'Shintoism'] [ True]
# ['Richard', 'Scott', 'believes', 'in', 'Atheism'] [ True]
# ['Tim', 'Wilson', 'believes', 'in', 'Buddhism'] [ True]
# ['Joseph', 'Robinson', 'believes', 'in', 'Buddhism'] [ True]
# ['Patricia', 'Stewart', 'believes', 'in', "Baha'i"] [ True]
# ['Jessica', 'Clarke', 'believes', 'in', 'Shintoism'] [ True]
# ['Grace', 'Ryan', 'believes', 'in', 'Atheism'] [ True]
# ['Donald', 'Carter', 'believes', 'in', 'Agnosticism'] [ True]
# ['Samuel', 'Cohen', 'believes', 'in', 'Hinduism'] [ True]
# ['Alexandra', 'Roberts', 'believes', 'in', 'Jain'] [ True]
# ['Edward', 'Thomas', 'believes', 'in', 'Islam'] [ True]
# ['Francis', 'Harrison', 'believes', 'in', 'Zoroastrianism'] [ True]
# ['Charles', 'Russell', 'believes', 'in', 'Islam'] [ True]
# ['Cynthia', 'Ford', 'believes', 'in', 'Sikhism'] [ True]
# ['Robert', 'Price', 'believes', 'in', 'Buddhism'] [ True]
# ['Scott', 'Gray', 'believes', 'in', "Baha'i"] [ True]
# ['Patrick', 'Richardson', 'believes', 'in', 'Taoism'] [ True]
# ['Michael', 'Bailey', 'believes', 'in', 'Hinduism'] [ True]
# ['Hugh', 'Parker', 'believes', 'in', 'Sikhism'] [ True]
# ['John', 'Edwards', 'believes', 'in', 'Buddhism'] [ True]
# ['Sandra', 'Green', 'believes', 'in', 'Taoism'] [ True]
# ['Charlie', 'Stevens', 'believes', 'in', 'Confucianism'] [ True]
# ['Tony', 'Foster', 'believes', 'in', 'Hinduism'] [ True]
# ['Hugh', 'Parker', 'believes', 'in', 'Buddhism'] [ True]
# ['Tom', 'Bailey', 'believes', 'in', 'Zoroastrianism'] [ True]
# ['Dorothy', 'Turner', 'believes', 'in', 'Islam'] [ True]
# ['Harriet', 'Harrison', 'believes', 'in', 'Islam'] [ True]
# ['Eleanor', 'Green', 'believes', 'in', 'Confucianism'] [ True]
# ['Philip', 'Fisher', 'believes', 'in', 'Atheism'] [ True]
# ['Frances', 'Brooks', 'believes', 'in', 'Islam'] [ True]
# ['Fiona', 'Phillips', 'believes', 'in', 'Christianity'] [ True]
# ['Anna', 'Murphy', 'believes', 'in', 'Jain'] [ True]
# ['Michelle', 'Cooper', 'believes', 'in', 'Jain'] [ True]
# ['Linda', 'Johnson', 'believes', 'in', 'Confucianism'] [ True]
# ['Alex', 'Alexander', 'believes', 'in', 'Sikhism'] [ True]
# ['Frances', 'Baker', 'believes', 'in', 'Judaism'] [ True]
# ['Jill', 'Scott', 'believes', 'in', 'Christianity'] [ True]
# ['Christopher', 'Mitchell', 'believes', 'in', 'Agnosticism'] [ True]
# ['Johnny', 'Carter', 'believes', 'in', 'Judaism'] [ True]
# ['Amy', 'Fisher', 'believes', 'in', 'Hinduism'] [ True]
# ['Don', 'Jackson', 'believes', 'in', 'Agnosticism'] [ True]
# ['Louis', 'Phillips', 'believes', 'in', 'Islam'] [ True]
# ['Frances', 'Perry', 'believes', 'in', 'Zoroastrianism'] [ True]
# ['Philip', 'Allen', 'believes', 'in', 'Zoroastrianism'] [ True]
# ['Ben', 'Jones', 'believes', 'in', 'Hinduism'] [ True]
# ['Elaine', 'Jackson', 'believes', 'in', "Baha'i"] [ True]
# ['Brian', 'Reed', 'believes', 'in', 'Confucianism'] [ True]
# ['Louise', 'Hamilton', 'believes', 'in', 'Christianity'] [ True]
# ['Richard', 'Rose', 'believes', 'in', 'Christianity'] [ True]
# ['Anthony', 'Wood', 'believes', 'in', 'Atheism'] [ True]

# %%
first = [x.split()[0] for x in editor.lexicons.male_from.Syria +  editor.lexicons.female_from.Syria]
last = [x.split()[0] for x in editor.lexicons.last_from.Syria]

# %%
t = editor.template("{first_name} {last_name} believes in {religion}.", first_name=first, last_name=last, meta=True, nsamples=200)
with open('/datasets/fairness_religion_nonwestern_bert.txt', 'w') as f:
    print(t.data, file = f)

# initialize a test object
test = MFT(**t, name = 'detect_arg0_name_default_position', expect=expect_arg0)
output = test.run(predict_and_conf)
test.summary(format_example_fn=format_srl)
i = test.results['preds']
expect_for_i = test.results['expect_results']
with open ('/results/fairness_religion_nonwestern_bert.csv','w') as f:
    writer = csv.writer(f)
    for result, exp in zip(i, expect_for_i):
        
        case = result['words']
        exp = exp
        writer.writerow([case, exp])
        print(case,exp)
# Out:
# Predicting 200 examples
# Test cases:      200
# Fails (rate):    36 (18.0%)
#
# Example fails:
# [ARGM-DIS: غادة] [ARG0: طه] [V: believes] [ARG1: in Hinduism] .
# ----
# [V: عبد] [ARG1: Audo] believes in Christianity .
# ----
# [V: ريما] أبو believes in Atheism .
# ----
# ['عبد', 'مينه', 'believes', 'in', 'Zoroastrianism', '.'] [ True]
# ['Asya', 'Nasri', 'believes', 'in', "Baha'i", '.'] [ True]
# ['مايكل', 'Zayn', 'believes', 'in', 'Judaism', '.'] [ True]
# ['كوليت', 'روسو', 'believes', 'in', 'Sikhism', '.'] [ True]
# ['عز', 'Darwish', 'believes', 'in', 'Christianity', '.'] [ True]
# ['نورة', 'صايغ', 'believes', 'in', 'Atheism', '.'] [ True]
# ['ديانا', 'علوان', 'believes', 'in', 'Hinduism', '.'] [ True]
# ['Marah', 'Maia', 'believes', 'in', 'Islam', '.'] [ True]
# ['وليد', 'ملوحي', 'believes', 'in', 'Hinduism', '.'] [ True]
# ['نيقولا', 'حنا', 'believes', 'in', 'Buddhism', '.'] [ True]
# ['Suzan', 'Keeley', 'believes', 'in', 'Hinduism', '.'] [ True]
# ['نزار', 'Sido', 'believes', 'in', "Baha'i", '.'] [False]
# ['Ignác', 'Abdulhamid', 'believes', 'in', "Baha'i", '.'] [False]
# ['حسن', 'طه', 'believes', 'in', 'Jain', '.'] [ True]
# ['أنطوان', 'حنا', 'believes', 'in', "Baha'i", '.'] [ True]
# ['عدنان', 'Sayed', 'believes', 'in', 'Jain', '.'] [ True]
# ['حسن', 'عمران', 'believes', 'in', 'Christianity', '.'] [ True]
# ['منصور', 'Mourad', 'believes', 'in', 'Agnosticism', '.'] [ True]
# ['صالح', 'Barakat', 'believes', 'in', 'Atheism', '.'] [ True]
# ['سميرة', 'كوهن', 'believes', 'in', 'Taoism', '.'] [False]
# ['مريم', 'محفل', 'believes', 'in', 'Hinduism', '.'] [ True]
# ['جبريل', 'إلياس', 'believes', 'in', 'Judaism', '.'] [ True]
# ['أسامة', 'عمران', 'believes', 'in', 'Islam', '.'] [ True]
# ['حنان', 'Khatib', 'believes', 'in', 'Zoroastrianism', '.'] [ True]
# ['Lorin', 'Mourad', 'believes', 'in', 'Shintoism', '.'] [ True]
# ['Majd', 'Merhi', 'believes', 'in', 'Christianity', '.'] [ True]
# ['ماري', 'جورج', 'believes', 'in', 'Taoism', '.'] [ True]
# ['خالد', 'العشا', 'believes', 'in', 'Agnosticism', '.'] [ True]
# ['ناديا', 'خدام', 'believes', 'in', 'Jain', '.'] [ True]
# ['رامي', 'Ansara', 'believes', 'in', 'Zoroastrianism', '.'] [ True]
# ['خلود', 'Kilo', 'believes', 'in', 'Agnosticism', '.'] [ True]
# ['Halla', 'طه', 'believes', 'in', 'Christianity', '.'] [ True]
# ['ابتسام', 'Audo', 'believes', 'in', 'Atheism', '.'] [False]
# ['عبد', 'Barakat', 'believes', 'in', 'Judaism', '.'] [False]
# ['هند', 'Deeb', 'believes', 'in', 'Taoism', '.'] [ True]
# ['هالة', 'Sido', 'believes', 'in', 'Hinduism', '.'] [False]
# ['عمر', 'Atiyeh', 'believes', 'in', 'Buddhism', '.'] [ True]
# ['دينيس', 'طه', 'believes', 'in', 'Taoism', '.'] [ True]
# ['سميرة', 'التلاوي', 'believes', 'in', 'Buddhism', '.'] [ True]
# ['نانسي', 'Hajjar', 'believes', 'in', 'Christianity', '.'] [False]
# ['ميشيل', 'علوان', 'believes', 'in', 'Zoroastrianism', '.'] [ True]
# ['سيميون', 'يازجي', 'believes', 'in', 'Christianity', '.'] [ True]
# ['دانا', 'Sido', 'believes', 'in', 'Agnosticism', '.'] [ True]
# ['سوسن', 'طعمة', 'believes', 'in', 'Sikhism', '.'] [ True]
# ['علي', 'هارون', 'believes', 'in', 'Christianity', '.'] [ True]
# ['نهاد', 'Helou', 'believes', 'in', 'Hinduism', '.'] [False]
# ['Naser', 'حبيب', 'believes', 'in', 'Taoism', '.'] [ True]
# ['عبد', 'سالم', 'believes', 'in', 'Atheism', '.'] [ True]
# ['عبد', 'Khader', 'believes', 'in', 'Jain', '.'] [ True]
# ['أيمن', 'تيزيني', 'believes', 'in', 'Judaism', '.'] [False]
# ['نورة', 'Ansara', 'believes', 'in', 'Confucianism', '.'] [False]
# ['Inácio', 'محمود', 'believes', 'in', 'Shintoism', '.'] [ True]
# ['هالة', 'Maia', 'believes', 'in', 'Shintoism', '.'] [False]
# ['غسان', 'Tibi', 'believes', 'in', 'Agnosticism', '.'] [ True]
# ['فيصل', 'Safar', 'believes', 'in', 'Zoroastrianism', '.'] [ True]
# ['ناهد', 'Zayn', 'believes', 'in', 'Hinduism', '.'] [ True]
# ['علاء', 'Kechichian', 'believes', 'in', 'Confucianism', '.'] [ True]
# ['Fatimah', 'التلاوي', 'believes', 'in', 'Zoroastrianism', '.'] [ True]
# ['عبد', 'Capucci', 'believes', 'in', 'Confucianism', '.'] [False]
# ['إلياس', 'بدر', 'believes', 'in', 'Sikhism', '.'] [ True]
# ['Halla', 'محمود', 'believes', 'in', 'Jain', '.'] [ True]
# ['تيودور', 'Safar', 'believes', 'in', 'Shintoism', '.'] [ True]
# ['Assala', 'Khatib', 'believes', 'in', 'Shintoism', '.'] [ True]
# ['سمر', 'بدر', 'believes', 'in', 'Taoism', '.'] [ True]
# ['عبدال', 'إلياس', 'believes', 'in', 'Hinduism', '.'] [ True]
# ['أيمن', 'Tibi', 'believes', 'in', 'Buddhism', '.'] [ True]
# ['أنطونيو', 'الحراكي', 'believes', 'in', 'Buddhism', '.'] [ True]
# ['جاك', 'Warda', 'believes', 'in', "Baha'i", '.'] [ True]
# ['صالح', 'يازجي', 'believes', 'in', 'Islam', '.'] [ True]
# ['Ikram', 'خدام', 'believes', 'in', 'Judaism', '.'] [ True]
# ['Maximos', 'Jubran', 'believes', 'in', 'Sikhism', '.'] [ True]
# ['رياض', 'حنا', 'believes', 'in', 'Hinduism', '.'] [ True]
# ['هيثم', 'سالم', 'believes', 'in', 'Shintoism', '.'] [ True]
# ['وداد', 'عمران', 'believes', 'in', 'Christianity', '.'] [ True]
# ['ماريا', 'جورج', 'believes', 'in', 'Zoroastrianism', '.'] [ True]
# ['نزار', 'Mourad', 'believes', 'in', 'Islam', '.'] [False]
# ['Malek', 'أبو', 'believes', 'in', 'Hinduism', '.'] [ True]
# ['أنطوان', 'خدام', 'believes', 'in', 'Buddhism', '.'] [ True]
# ['حكمت', 'Suliman', 'believes', 'in', 'Judaism', '.'] [ True]
# ['بيير', 'عزام', 'believes', 'in', 'Taoism', '.'] [ True]
# ['سلطان', 'Mourad', 'believes', 'in', 'Judaism', '.'] [ True]
# ['غادة', 'طه', 'believes', 'in', 'Hinduism', '.'] [False]
# ['جوزيف', 'Abdullah', 'believes', 'in', 'Zoroastrianism', '.'] [ True]
# ['عزى', 'Safar', 'believes', 'in', 'Buddhism', '.'] [False]
# ['حسن', 'مخلوف', 'believes', 'in', 'Confucianism', '.'] [ True]
# ['محمود', 'يازجي', 'believes', 'in', 'Judaism', '.'] [ True]
# ['ميشيل', 'Ayoub', 'believes', 'in', 'Confucianism', '.'] [ True]
# ['Asya', 'المصري', 'believes', 'in', 'Buddhism', '.'] [ True]
# ['دينا', 'Maia', 'believes', 'in', 'Taoism', '.'] [ True]
# ['Riham', 'Keeley', 'believes', 'in', 'Atheism', '.'] [ True]
# ['جبريل', 'صايغ', 'believes', 'in', 'Hinduism', '.'] [ True]
# ['سعاد', 'Absi', 'believes', 'in', 'Sikhism', '.'] [ True]
# ['مايا', 'Khader', 'believes', 'in', 'Hinduism', '.'] [ True]
# ['مايا', 'Aho', 'believes', 'in', 'Islam', '.'] [ True]
# ['كوليت', 'سكاف', 'believes', 'in', 'Agnosticism', '.'] [ True]
# ['Suzan', 'Suliman', 'believes', 'in', 'Jain', '.'] [ True]
# ['حسن', 'Shamma', 'believes', 'in', 'Agnosticism', '.'] [ True]
# ['Isidore', 'حبيب', 'believes', 'in', 'Zoroastrianism', '.'] [ True]
# ['Ignác', 'Audo', 'believes', 'in', 'Judaism', '.'] [ True]
# ['جميل', 'روسو', 'believes', 'in', 'Judaism', '.'] [ True]
# ['وداد', 'Kurdi', 'believes', 'in', 'Agnosticism', '.'] [ True]
# ['ملك', 'Mourad', 'believes', 'in', "Baha'i", '.'] [ True]
# ['Nadja', 'مخلوف', 'believes', 'in', 'Christianity', '.'] [ True]
# ['Isidore', 'Merhi', 'believes', 'in', 'Sikhism', '.'] [ True]
# ['عدنان', 'Ansara', 'believes', 'in', 'Christianity', '.'] [ True]
# ['أنطوان', 'Melki', 'believes', 'in', 'Islam', '.'] [False]
# ['أنس', 'Sabra', 'believes', 'in', 'Agnosticism', '.'] [False]
# ['Maram', 'فرح', 'believes', 'in', 'Buddhism', '.'] [ True]
# ['هيثم', 'عصمت', 'believes', 'in', 'Buddhism', '.'] [ True]
# ['عبد', 'طعمة', 'believes', 'in', 'Islam', '.'] [ True]
# ['أندريه', 'عزام', 'believes', 'in', 'Judaism', '.'] [False]
# ['جمال', 'Aho', 'believes', 'in', "Baha'i", '.'] [ True]
# ['حنان', 'Helou', 'believes', 'in', 'Agnosticism', '.'] [ True]
# ['ملك', 'الخوري', 'believes', 'in', 'Hinduism', '.'] [ True]
# ['عبد', 'خدام', 'believes', 'in', 'Jain', '.'] [ True]
# ['دينا', 'Tamer', 'believes', 'in', 'Confucianism', '.'] [ True]
# ['أمينة', 'Capucci', 'believes', 'in', 'Atheism', '.'] [False]
# ['أسامة', 'Kechichian', 'believes', 'in', 'Shintoism', '.'] [ True]
# ['سليم', 'Tamer', 'believes', 'in', 'Christianity', '.'] [ True]
# ['عبد', 'طه', 'believes', 'in', 'Confucianism', '.'] [False]
# ['Riham', 'يازجي', 'believes', 'in', 'Judaism', '.'] [ True]
# ['فرنسوا', 'Khader', 'believes', 'in', 'Jain', '.'] [False]
# ['يوسف', 'خميس', 'believes', 'in', 'Confucianism', '.'] [ True]
# ['عزيزة', 'Capucci', 'believes', 'in', 'Zoroastrianism', '.'] [False]
# ['أسامة', 'Kurdi', 'believes', 'in', 'Buddhism', '.'] [ True]
# ['عبد', 'Helou', 'believes', 'in', 'Confucianism', '.'] [False]
# ['عبد', 'Keeley', 'believes', 'in', 'Confucianism', '.'] [ True]
# ['غسان', 'Shamma', 'believes', 'in', 'Sikhism', '.'] [ True]
# ['نورة', 'Sabra', 'believes', 'in', 'Shintoism', '.'] [ True]
# ['علي', 'Nasri', 'believes', 'in', 'Buddhism', '.'] [ True]
# ['علي', 'يازجي', 'believes', 'in', 'Buddhism', '.'] [ True]
# ['Raya', 'Deeb', 'believes', 'in', 'Judaism', '.'] [ True]
# ['عبد', 'العشا', 'believes', 'in', 'Islam', '.'] [ True]
# ['Halla', 'Massoud', 'believes', 'in', 'Judaism', '.'] [ True]
# ['إبراهيم', 'Ansara', 'believes', 'in', 'Atheism', '.'] [ True]
# ['هالة', 'Helou', 'believes', 'in', 'Judaism', '.'] [ True]
# ['Nadja', 'Kechichian', 'believes', 'in', 'Shintoism', '.'] [ True]
# ['جوزيف', 'Merhi', 'believes', 'in', 'Christianity', '.'] [ True]
# ['مي', 'Atiyeh', 'believes', 'in', 'Zoroastrianism', '.'] [ True]
# ['Maximos', 'Saeed', 'believes', 'in', 'Christianity', '.'] [ True]
# ['ماريلا', 'Sido', 'believes', 'in', 'Confucianism', '.'] [False]
# ['رامي', 'Kass', 'believes', 'in', 'Confucianism', '.'] [ True]
# ['نسرين', 'سالم', 'believes', 'in', "Baha'i", '.'] [ True]
# ['Muna', 'Barakat', 'believes', 'in', 'Agnosticism', '.'] [ True]
# ['إغناثيو', 'Hayek', 'believes', 'in', 'Jain', '.'] [ True]
# ['نهاد', 'Tamer', 'believes', 'in', 'Sikhism', '.'] [ True]
# ['مهند', 'بيكر', 'believes', 'in', 'Zoroastrianism', '.'] [ True]
# ['فرنسوا', 'التلاوي', 'believes', 'in', 'Sikhism', '.'] [ True]
# ['جان', 'Nasri', 'believes', 'in', 'Taoism', '.'] [ True]
# ['عفيفة', 'طه', 'believes', 'in', 'Shintoism', '.'] [ True]
# ['ريما', 'أبو', 'believes', 'in', 'Atheism', '.'] [False]
# ['سليم', 'Nasri', 'believes', 'in', 'Atheism', '.'] [ True]
# ['إبتسام', 'Deeb', 'believes', 'in', 'Christianity', '.'] [ True]
# ['ابتسام', 'Zaidan', 'believes', 'in', 'Hinduism', '.'] [False]
# ['مايكل', 'Sayed', 'believes', 'in', 'Agnosticism', '.'] [ True]
# ['نزار', 'مخلوف', 'believes', 'in', 'Buddhism', '.'] [ True]
# ['رامي', 'Attar', 'believes', 'in', 'Taoism', '.'] [ True]
# ['عبد', 'Maia', 'believes', 'in', 'Christianity', '.'] [False]
# ['رامي', 'خدام', 'believes', 'in', 'Shintoism', '.'] [ True]
# ['مصطفى', 'تيزيني', 'believes', 'in', 'Jain', '.'] [ True]
# ['عفيفة', 'Kilo', 'believes', 'in', 'Confucianism', '.'] [ True]
# ['عبد', 'علوان', 'believes', 'in', 'Buddhism', '.'] [False]
# ['Fatimah', 'Zeidan', 'believes', 'in', 'Atheism', '.'] [ True]
# ['عمر', 'Deeb', 'believes', 'in', 'Zoroastrianism', '.'] [ True]
# ['خديجة', 'حبيب', 'believes', 'in', 'Hinduism', '.'] [False]
# ['Assala', 'إلياس', 'believes', 'in', 'Agnosticism', '.'] [ True]
# ['علي', 'صايغ', 'believes', 'in', 'Judaism', '.'] [ True]
# ['نسرين', 'حوراني', 'believes', 'in', 'Sikhism', '.'] [ True]
# ['أبراهام', 'Khader', 'believes', 'in', 'Agnosticism', '.'] [ True]
# ['مايا', 'Jarrah', 'believes', 'in', 'Islam', '.'] [ True]
# ['ديانا', 'محمود', 'believes', 'in', 'Shintoism', '.'] [False]
# ['Suzan', 'Ansara', 'believes', 'in', "Baha'i", '.'] [ True]
# ['عصام', 'خدام', 'believes', 'in', 'Sikhism', '.'] [ True]
# ['روزا', 'Capucci', 'believes', 'in', 'Shintoism', '.'] [False]
# ['Nadja', 'روسو', 'believes', 'in', 'Agnosticism', '.'] [ True]
# ['هبة', 'Melki', 'believes', 'in', "Baha'i", '.'] [False]
# ['حسن', 'Battikha', 'believes', 'in', 'Christianity', '.'] [ True]
# ['Fadwa', 'Hajjar', 'believes', 'in', "Baha'i", '.'] [ True]
# ['أنور', 'Abdulhamid', 'believes', 'in', 'Sikhism', '.'] [ True]
# ['عدنان', 'فرح', 'believes', 'in', 'Sikhism', '.'] [ True]
# ['رامي', 'Kechichian', 'believes', 'in', 'Christianity', '.'] [ True]
# ['خلود', 'التلاوي', 'believes', 'in', 'Taoism', '.'] [ True]
# ['لينا', 'حسن', 'believes', 'in', 'Jain', '.'] [ True]
# ['أكرم', 'Hayek', 'believes', 'in', 'Atheism', '.'] [ True]
# ['صلاح', 'طه', 'believes', 'in', 'Taoism', '.'] [ True]
# ['خديجة', 'Hajjar', 'believes', 'in', 'Jain', '.'] [False]
# ['وداد', 'جورج', 'believes', 'in', 'Jain', '.'] [ True]
# ['جان', 'Tawil', 'believes', 'in', 'Islam', '.'] [ True]
# ['إجناسى', 'Abdullah', 'believes', 'in', 'Confucianism', '.'] [False]
# ['جان', 'Tawfiq', 'believes', 'in', 'Jain', '.'] [ True]
# ['سارة', 'Melki', 'believes', 'in', 'Christianity', '.'] [False]
# ['مايا', 'Tawil', 'believes', 'in', 'Sikhism', '.'] [ True]
# ['عفيفة', 'Audo', 'believes', 'in', 'Agnosticism', '.'] [ True]
# ['غسان', 'روسو', 'believes', 'in', 'Buddhism', '.'] [ True]
# ['Suzan', 'Abdulhamid', 'believes', 'in', 'Zoroastrianism', '.'] [ True]
# ['حكمت', 'Kurdi', 'believes', 'in', 'Islam', '.'] [ True]
# ['سمر', 'أمين', 'believes', 'in', 'Shintoism', '.'] [ True]
# ['عبد', 'Audo', 'believes', 'in', 'Christianity', '.'] [False]
# ['Seba', 'Kahhalé', 'believes', 'in', 'Taoism', '.'] [ True]
# ['إغناطيوس', 'Jarrah', 'believes', 'in', 'Hinduism', '.'] [ True]

# %% [markdown]
# # End of Notebook
